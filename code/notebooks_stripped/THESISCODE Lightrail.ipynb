# %%
import geopandas as gpd

shapefile_path = 'C:/Users/m1llz/Downloads/UNI FILES/tpa_spatial_tz_nsw_2016_shp/TZ_NSW_2016.dbf'



    
gdf = gpd.read_file(shapefile_path)

# %%
gdf

# %%
sorted_gdf=gdf.sort_values(by='TZ16_CODE', ascending = True)

sorted_gdf.to_file('sorted_TZ_NSW_2016.dbf')

sorted_gdf.reset_index(drop=True, inplace=True)

sorted_gdf

# %%
import pandas as pd

csv_path = 'C:/Users/m1llz/Downloads/UNI FILES/tzp22-employment-by-tz-2016-2066.csv'
csv_job_data = pd.read_csv(csv_path)
csv_job_data

# %%
#print(sorted_gdf.dtypes)
#print(csv_job_data.dtypes)

if sorted_gdf.iloc[50,0] == csv_job_data.iloc[50,0]:
    print('yay')
    print(sorted_gdf.iloc[50,0])
    print(csv_job_data.iloc[50,0])

else:
    print('oh no')

# %%
common_column = 'TZ16_CODE'
columns_to_include =['SA2_Name16', 'SA3_Name16', 'SA4_Name16', 'LGA_Name18', 'EMP_2016'] 

# Ensure both have the same column names for the common identifier

#sorted_gdf.rename(columns={'TZ16_CODE': common_column}, inplace=True)
#csv_job_data.rename(columns={'TZ16_CODE': common_column}, inplace=True)



# Perform merge based on the common identifier and selected columns
merged_data = sorted_gdf.join(csv_job_data[columns_to_include])
merged_data

# %%
import matplotlib.pyplot as plt


filtered_gdf = merged_data[merged_data["SA4_Name16"].str.contains('Sydney')]

filtered_gdf


#filtered_gdf.plot()

#plt.show()

# %%
shapefile_path_osm = 'C:/Users/m1llz/Downloads/UNI FILES/sydney-osm-withsydneymetrowest.osm.pbf'

#"C:\Users\m1llz\Downloads\UNI FILES\V2OSM-plswork.osm.pbf"
#"C:\Users\m1llz\Downloads\UNI FILES\UNISTUFF V2\full_greater_sydney_gtfs_static_0_editing.zip"
#"C:\Users\m1llz\Downloads\UNI FILES\UNISTUFF V2\full_greater_sydney_gtfs_static_0 (1).zip"

# %%
filtered_gdf.explore()

# %%
filtered_gdf.loc[:, 'id'] = filtered_gdf['TZ16_CODE'].copy()

# %%
filtered_gdf

# %%
filtered_gdf2 = filtered_gdf.to_crs('epsg:3308')
filtered_gdf2

# %%
origins = filtered_gdf2.copy()
origins["geometry"] = origins.geometry.centroid
destinations = filtered_gdf2.copy()
destinations["geometry"] = destinations.geometry.centroid

# %%
print(filtered_gdf2.loc[0])
print(filtered_gdf2.loc[2565])

# %%
trips_txt_path = 'C:/Users/m1llz/Downloads/UNI FILES/UNISTUFF V2/new_base_case_with_smw_v4_lightrail/trips.txt'
trips_txt_data = pd.read_csv(trips_txt_path)
#trips_txt_data
#filtered_trips_txt_data = trips_txt_data[(trips_txt_data['route_id']=='Bondi Junction to Waterfall or Cronull') |  (trips_txt_data['route_direction']=='Waterfall or Cronulla to Bondi Junction')]

filtered_trips_txt_data = trips_txt_data[trips_txt_data['route_id']=='78-L3-sj2-1']


filtered_trips_txt_data

# %%
filtered_trips_txt_data0 = filtered_trips_txt_data[filtered_trips_txt_data['direction_id']==1]
filtered_trips_txt_data0

# %%
trip_ids = filtered_trips_txt_data0['trip_id'].unique()
print(trip_ids)
print(len(trip_ids))

# %%
stop_times_txt_path = 'C:/Users/m1llz/Downloads/UNI FILES/UNISTUFF V2/new_base_case_with_smw_v4_lightrail/stop_times.txt'
stop_times_txt_data = pd.read_csv(stop_times_txt_path)
sorted_stop_times_txt_data = stop_times_txt_data[stop_times_txt_data['trip_id'].isin(trip_ids)]
sorted_stop_times_txt_data

# %%
sorted_stop_times_txt_data1 = sorted_stop_times_txt_data[sorted_stop_times_txt_data['arrival_time'].str.startswith('08')]
sorted_stop_times_txt_data1

# %%
trip_ids0 = sorted_stop_times_txt_data1['trip_id'].unique()
print(trip_ids0)
print(len(trip_ids0))

# %%
def test_function(x):
    return x

print(test_function(5))

# %%
from datetime import datetime, timedelta


def process_trip(trip_id):

    global stop_times_txt_data

    truth_condition = (stop_times_txt_data['stop_sequence'] == 1) & (stop_times_txt_data['stop_id'] != 203288) & (stop_times_txt_data['stop_id'] != 203289) & (stop_times_txt_data['trip_id'] == trip_id)
    if truth_condition.any():
        print('Not working for this trip')
        return 
    # Filter DataFrame for the specific trip_id
    #trip_df = stop_times_txt_data[stop_times_txt_data['trip_id'] == trip_id].copy()
    filtered_row = stop_times_txt_data[(stop_times_txt_data['trip_id'] == trip_id) & (stop_times_txt_data['stop_sequence'] == 1)].copy()
    filtered_row1 = stop_times_txt_data[(stop_times_txt_data['trip_id'] == trip_id) & (stop_times_txt_data['stop_sequence'] == 1)].copy()
    filtered_row2 = stop_times_txt_data[(stop_times_txt_data['trip_id'] == trip_id) & (stop_times_txt_data['stop_sequence'] == 1)].copy()
    filtered_row3 = stop_times_txt_data[(stop_times_txt_data['trip_id'] == trip_id) & (stop_times_txt_data['stop_sequence'] == 1)].copy()
    filtered_row4 = stop_times_txt_data[(stop_times_txt_data['trip_id'] == trip_id) & (stop_times_txt_data['stop_sequence'] == 1)].copy()
    filtered_row5 = stop_times_txt_data[(stop_times_txt_data['trip_id'] == trip_id) & (stop_times_txt_data['stop_sequence'] == 1)].copy()
    filtered_row6 = stop_times_txt_data[(stop_times_txt_data['trip_id'] == trip_id) & (stop_times_txt_data['stop_sequence'] == 1)].copy()
    filtered_row7 = stop_times_txt_data[(stop_times_txt_data['trip_id'] == trip_id) & (stop_times_txt_data['stop_sequence'] == 1)].copy()
    filtered_row8 = stop_times_txt_data[(stop_times_txt_data['trip_id'] == trip_id) & (stop_times_txt_data['stop_sequence'] == 1)].copy()

   
    
    filtered_row['stop_id'] = 20361060
    filtered_row1['stop_id'] = 20361050
    filtered_row2['stop_id'] = 20361040
    filtered_row3['stop_id'] = 20361030
    filtered_row4['stop_id'] = 20361020
    filtered_row5['stop_id'] = 20351040
    filtered_row6['stop_id'] = 20351030
    filtered_row7['stop_id'] = 20351020
    filtered_row8['stop_id'] = 20321020


    filtered_row1['stop_sequence'] = 2
    filtered_row2['stop_sequence'] = 3
    filtered_row3['stop_sequence'] = 4
    filtered_row4['stop_sequence'] = 5
    filtered_row5['stop_sequence'] = 6
    filtered_row6['stop_sequence'] = 7
    filtered_row7['stop_sequence'] = 8
    filtered_row8['stop_sequence'] = 9
   

    filtered_row1['drop_off_type'] = 0
    filtered_row2['drop_off_type'] = 0
    filtered_row3['drop_off_type'] = 0
    filtered_row4['drop_off_type'] = 0
    filtered_row5['drop_off_type'] = 0
    filtered_row6['drop_off_type'] = 0
    filtered_row7['drop_off_type'] = 0
    filtered_row8['drop_off_type'] = 0
    
    arrival_time_str = filtered_row['arrival_time'].values[0]
    arrival_time = datetime.strptime(arrival_time_str, '%H:%M:%S')
    new_arrival_time = arrival_time - timedelta(minutes=20)
    new_arrival_time_str = new_arrival_time.strftime('%H:%M:%S')
    filtered_row['arrival_time'] = new_arrival_time_str

    departure_time_str = filtered_row['departure_time'].values[0]
    departure_time = datetime.strptime(departure_time_str, '%H:%M:%S')
    new_departure_time = departure_time - timedelta(minutes=20)
    new_departure_time_str = new_departure_time.strftime('%H:%M:%S')
    filtered_row['departure_time'] = new_departure_time_str




    arrival_time_str4 = filtered_row1['arrival_time'].values[0]
    arrival_time4 = datetime.strptime(arrival_time_str4, '%H:%M:%S')
    new_arrival_time4 = arrival_time4 - timedelta(minutes=16, seconds=5)
    new_arrival_time_str4 = new_arrival_time4.strftime('%H:%M:%S')
    filtered_row1['arrival_time'] = new_arrival_time_str4

    departure_time_str4 = filtered_row1['departure_time'].values[0]
    departure_time4 = datetime.strptime(departure_time_str4, '%H:%M:%S')
    new_departure_time4 = departure_time4 - timedelta(minutes=16)
    new_departure_time_str4 = new_departure_time4.strftime('%H:%M:%S')
    filtered_row1['departure_time'] = new_departure_time_str4


    arrival_time_str5 = filtered_row2['arrival_time'].values[0]
    arrival_time5 = datetime.strptime(arrival_time_str5, '%H:%M:%S')
    new_arrival_time5 = arrival_time5 - timedelta(minutes=14, seconds=5)
    new_arrival_time_str5 = new_arrival_time5.strftime('%H:%M:%S')
    filtered_row2['arrival_time'] = new_arrival_time_str5

    departure_time_str5 = filtered_row2['departure_time'].values[0]
    departure_time5 = datetime.strptime(departure_time_str5, '%H:%M:%S')
    new_departure_time5 = departure_time5 - timedelta(minutes=14)
    new_departure_time_str5 = new_departure_time5.strftime('%H:%M:%S')
    filtered_row2['departure_time'] = new_departure_time_str5


    arrival_time_str6 = filtered_row3['arrival_time'].values[0]
    arrival_time6 = datetime.strptime(arrival_time_str6, '%H:%M:%S')
    new_arrival_time6 = arrival_time6 - timedelta(minutes=12, seconds=5)
    new_arrival_time_str6 = new_arrival_time6.strftime('%H:%M:%S')
    filtered_row3['arrival_time'] = new_arrival_time_str6

    departure_time_str6 = filtered_row3['departure_time'].values[0]
    departure_time6 = datetime.strptime(departure_time_str6, '%H:%M:%S')
    new_departure_time6 = departure_time6 - timedelta(minutes=12)
    new_departure_time_str6 = new_departure_time6.strftime('%H:%M:%S')
    filtered_row3['departure_time'] = new_departure_time_str6


    arrival_time_str7 = filtered_row4['arrival_time'].values[0]
    arrival_time7 = datetime.strptime(arrival_time_str7, '%H:%M:%S')
    new_arrival_time7 = arrival_time7 - timedelta(minutes=10, seconds=5)
    new_arrival_time_str7 = new_arrival_time7.strftime('%H:%M:%S')
    filtered_row4['arrival_time'] = new_arrival_time_str7

    departure_time_str7 = filtered_row4['departure_time'].values[0]
    departure_time7 = datetime.strptime(departure_time_str7, '%H:%M:%S')
    new_departure_time7 = departure_time7 - timedelta(minutes=10)
    new_departure_time_str7 = new_departure_time7.strftime('%H:%M:%S')
    filtered_row4['departure_time'] = new_departure_time_str7


    arrival_time_str8 = filtered_row5['arrival_time'].values[0]
    arrival_time8 = datetime.strptime(arrival_time_str8, '%H:%M:%S')
    new_arrival_time8 = arrival_time8 - timedelta(minutes=8, seconds=5)
    new_arrival_time_str8 = new_arrival_time8.strftime('%H:%M:%S')
    filtered_row5['arrival_time'] = new_arrival_time_str8

    departure_time_str8 = filtered_row5['departure_time'].values[0]
    departure_time8 = datetime.strptime(departure_time_str8, '%H:%M:%S')
    new_departure_time8 = departure_time8 - timedelta(minutes=8)
    new_departure_time_str8 = new_departure_time8.strftime('%H:%M:%S')
    filtered_row5['departure_time'] = new_departure_time_str8


    arrival_time_str9 = filtered_row6['arrival_time'].values[0]
    arrival_time9 = datetime.strptime(arrival_time_str9, '%H:%M:%S')
    new_arrival_time9 = arrival_time9 - timedelta(minutes=6, seconds=5)
    new_arrival_time_str9 = new_arrival_time9.strftime('%H:%M:%S')
    filtered_row6['arrival_time'] = new_arrival_time_str9

    departure_time_str9 = filtered_row6['departure_time'].values[0]
    departure_time9 = datetime.strptime(departure_time_str9, '%H:%M:%S')
    new_departure_time9 = departure_time9 - timedelta(minutes=6)
    new_departure_time_str9 = new_departure_time9.strftime('%H:%M:%S')
    filtered_row6['departure_time'] = new_departure_time_str9

    arrival_time_str10 = filtered_row7['arrival_time'].values[0]
    arrival_time10 = datetime.strptime(arrival_time_str10, '%H:%M:%S')
    new_arrival_time10 = arrival_time10 - timedelta(minutes=4, seconds=5)
    new_arrival_time_str10 = new_arrival_time10.strftime('%H:%M:%S')
    filtered_row7['arrival_time'] = new_arrival_time_str10

    departure_time_str10 = filtered_row7['departure_time'].values[0]
    departure_time10 = datetime.strptime(departure_time_str10, '%H:%M:%S')
    new_departure_time10 = departure_time10 - timedelta(minutes=4)
    new_departure_time_str10 = new_departure_time10.strftime('%H:%M:%S')
    filtered_row7['departure_time'] = new_departure_time_str10


    arrival_time_str11 = filtered_row8['arrival_time'].values[0]
    arrival_time11 = datetime.strptime(arrival_time_str11, '%H:%M:%S')
    new_arrival_time11 = arrival_time11 - timedelta(minutes=2, seconds=5)
    new_arrival_time_str11 = new_arrival_time11.strftime('%H:%M:%S')
    filtered_row8['arrival_time'] = new_arrival_time_str11

    departure_time_str11 = filtered_row8['departure_time'].values[0]
    departure_time11 = datetime.strptime(departure_time_str11, '%H:%M:%S')
    new_departure_time11 = departure_time11 - timedelta(minutes=2)
    new_departure_time_str11 = new_departure_time11.strftime('%H:%M:%S')
    filtered_row8['departure_time'] = new_departure_time_str11


    condition = (stop_times_txt_data['trip_id'] == trip_id) & ((stop_times_txt_data['stop_id'] == 203288) | (stop_times_txt_data['stop_id'] == 203289))
    # Extract the current arrival time
    current_arrival_time_str1 = stop_times_txt_data.loc[condition, 'arrival_time'].values[0]
    # Convert the arrival time to a datetime object
    current_arrival_time1 = datetime.strptime(current_arrival_time_str1, '%H:%M:%S')
    # Subtract one minute
    new_arrival_time1 = current_arrival_time1 - timedelta(seconds=5)
    # Convert back to string
    new_arrival_time_str1 = new_arrival_time1.strftime('%H:%M:%S')
    # Update the DataFrame
    stop_times_txt_data.loc[condition, 'arrival_time'] = new_arrival_time_str1

    stop_times_txt_data.loc[condition, 'drop_off_type'] = 0

    stop_times_txt_data.loc[stop_times_txt_data['trip_id']==trip_id, 'stop_sequence'] += 9


    index_to_insert_before = stop_times_txt_data[((stop_times_txt_data['stop_id'] == 203288) | (stop_times_txt_data['stop_id'] == 203289)) & (stop_times_txt_data['trip_id']== trip_id)].index[0]

    # Step 2: Create the DataFrames for concatenation
    df_top = stop_times_txt_data.iloc[:index_to_insert_before]  # DataFrame before the insertion point
    df_bottom = stop_times_txt_data.iloc[index_to_insert_before:]  # DataFrame after the insertion point



    rows_to_insert = [filtered_row,filtered_row1,filtered_row2,filtered_row3,filtered_row4,filtered_row5,filtered_row6,filtered_row7,filtered_row8]

    insert_df = pd.concat(rows_to_insert, ignore_index=True)

    # Step 3: Insert the new row and concatenate
    stop_times_txt_data = pd.concat([df_top, insert_df, df_bottom], ignore_index=True).reset_index(drop=True)
    stop_tines_txt_data = stop_times_txt_data.drop_duplicates()
    
    #index_to_insert_before = stop_times_txt_data[stop_times_txt_data['stop_sequence'] == 0].index[0]
    #stop_times_txt_data.loc[index_to_insert_before] = filtered_row.iloc[0]
    #stop_times_txt_data = pd.concat([stop_times_txt_data.iloc[:index_to_insert_before], filtered_row, stop_times_txt_data.iloc[index_to_insert_before:]]).reset_index(drop=True)


       
    
    return

# %%
process_trip('38795-71094:1000')

# %%
ticker = 0

for trip in trip_ids0:
    process_trip(trip)
    ticker +=1
    print(ticker)

# %%
test_output = stop_times_txt_data[stop_times_txt_data['trip_id']=='38795-71094:1000']
test_output

# %%
print(test_output['arrival_time'].dtype)

# %%
unique_types = stop_times_txt_data['departure_time'].map(type).unique()
print("Unique data types in the column:", unique_types)

# %%
filtered_trips_txt_data1 = filtered_trips_txt_data[filtered_trips_txt_data['direction_id']==0]
filtered_trips_txt_data1

# %%
trip_ids1 = filtered_trips_txt_data1['trip_id'].unique()
print(trip_ids1)
print(len(trip_ids1))

# %%
sorted_stop_times_txt_data1 = stop_times_txt_data[stop_times_txt_data['trip_id'].isin(trip_ids1)]
sorted_stop_times_txt_data1

# %%
sorted_stop_times_txt_data2 = sorted_stop_times_txt_data1[sorted_stop_times_txt_data1['arrival_time'].str.startswith('08')]
sorted_stop_times_txt_data2

# %%
trip_ids2 = sorted_stop_times_txt_data2['trip_id'].unique()
print(trip_ids2)
print(len(trip_ids2))

# %%
final_stop_sequence = stop_times_txt_data[stop_times_txt_data['trip_id'] == '38795-71092:1000']['stop_sequence'].max()
final_stop_sequence

# %%
def process_trip1(trip_id):

    global stop_times_txt_data

    final_stop_sequence = stop_times_txt_data[stop_times_txt_data['trip_id'] == trip_id]['stop_sequence'].max()

    truth_condition = (stop_times_txt_data['stop_sequence'] == final_stop_sequence) & (stop_times_txt_data['stop_id'] != 203288) & (stop_times_txt_data['stop_id'] != 203289) & (stop_times_txt_data['trip_id'] == trip_id)
    if truth_condition.any():
        'Does not work for this Trip'
        return
    # Filter DataFrame for the specific trip_id
    #trip_df = stop_times_txt_data[stop_times_txt_data['trip_id'] == trip_id].copy()
    filtered_row = stop_times_txt_data[(stop_times_txt_data['trip_id'] == trip_id) & (stop_times_txt_data['stop_sequence'] == final_stop_sequence)].copy()
    filtered_row1 = stop_times_txt_data[(stop_times_txt_data['trip_id'] == trip_id) & (stop_times_txt_data['stop_sequence'] == final_stop_sequence)].copy()
    filtered_row2 = stop_times_txt_data[(stop_times_txt_data['trip_id'] == trip_id) & (stop_times_txt_data['stop_sequence'] == final_stop_sequence)].copy()
    filtered_row3 = stop_times_txt_data[(stop_times_txt_data['trip_id'] == trip_id) & (stop_times_txt_data['stop_sequence'] == final_stop_sequence)].copy()
    filtered_row4 = stop_times_txt_data[(stop_times_txt_data['trip_id'] == trip_id) & (stop_times_txt_data['stop_sequence'] == final_stop_sequence)].copy()
    filtered_row5 = stop_times_txt_data[(stop_times_txt_data['trip_id'] == trip_id) & (stop_times_txt_data['stop_sequence'] == final_stop_sequence)].copy()
    filtered_row6 = stop_times_txt_data[(stop_times_txt_data['trip_id'] == trip_id) & (stop_times_txt_data['stop_sequence'] == final_stop_sequence)].copy()
    filtered_row7 = stop_times_txt_data[(stop_times_txt_data['trip_id'] == trip_id) & (stop_times_txt_data['stop_sequence'] == final_stop_sequence)].copy()
    filtered_row8 = stop_times_txt_data[(stop_times_txt_data['trip_id'] == trip_id) & (stop_times_txt_data['stop_sequence'] == final_stop_sequence)].copy()

    
    filtered_row['stop_id'] = 20321020
    filtered_row1['stop_id'] = 20351020
    filtered_row2['stop_id'] = 20351030
    filtered_row3['stop_id'] = 20351040
    filtered_row4['stop_id'] = 20361020
    filtered_row5['stop_id'] = 20361030
    filtered_row6['stop_id'] = 20361040
    filtered_row7['stop_id'] = 20361050
    filtered_row8['stop_id'] = 20361060
    
    arrival_time_str = filtered_row['arrival_time'].values[0]
    arrival_time = datetime.strptime(arrival_time_str, '%H:%M:%S')
    new_arrival_time = arrival_time + timedelta(minutes=2)
    new_arrival_time_str = new_arrival_time.strftime('%H:%M:%S')
    filtered_row['arrival_time'] = new_arrival_time_str

    departure_time_str = filtered_row['departure_time'].values[0]
    departure_time = datetime.strptime(departure_time_str, '%H:%M:%S')
    new_departure_time = departure_time + timedelta(minutes=2, seconds=5)
    new_departure_time_str = new_departure_time.strftime('%H:%M:%S')
    filtered_row['departure_time'] = new_departure_time_str


    arrival_time_str3 = filtered_row1['arrival_time'].values[0]
    arrival_time3 = datetime.strptime(arrival_time_str3, '%H:%M:%S')
    new_arrival_time3 = arrival_time3 + timedelta(minutes=4)
    new_arrival_time_str3 = new_arrival_time3.strftime('%H:%M:%S')
    filtered_row1['arrival_time'] = new_arrival_time_str3

    departure_time_str3 = filtered_row1['departure_time'].values[0]
    departure_time3 = datetime.strptime(departure_time_str3, '%H:%M:%S')
    new_departure_time3 = departure_time3 + timedelta(minutes=4, seconds=5)
    new_departure_time_str3 = new_departure_time3.strftime('%H:%M:%S')
    filtered_row1['departure_time'] = new_departure_time_str3


    arrival_time_str4 = filtered_row2['arrival_time'].values[0]
    arrival_time4 = datetime.strptime(arrival_time_str4, '%H:%M:%S')
    new_arrival_time4 = arrival_time4 + timedelta(minutes=6)
    new_arrival_time_str4 = new_arrival_time4.strftime('%H:%M:%S')
    filtered_row2['arrival_time'] = new_arrival_time_str4

    departure_time_str4 = filtered_row2['departure_time'].values[0]
    departure_time4 = datetime.strptime(departure_time_str4, '%H:%M:%S')
    new_departure_time4 = departure_time4 + timedelta(minutes=6, seconds=5)
    new_departure_time_str4 = new_departure_time4.strftime('%H:%M:%S')
    filtered_row2['departure_time'] = new_departure_time_str4

    arrival_time_str5 = filtered_row3['arrival_time'].values[0]
    arrival_time5 = datetime.strptime(arrival_time_str5, '%H:%M:%S')
    new_arrival_time5 = arrival_time5 + timedelta(minutes=8)
    new_arrival_time_str5 = new_arrival_time5.strftime('%H:%M:%S')
    filtered_row3['arrival_time'] = new_arrival_time_str5

    departure_time_str5 = filtered_row3['departure_time'].values[0]
    departure_time5 = datetime.strptime(departure_time_str5, '%H:%M:%S')
    new_departure_time5 = departure_time5 + timedelta(minutes=8, seconds=5)
    new_departure_time_str5 = new_departure_time5.strftime('%H:%M:%S')
    filtered_row3['departure_time'] = new_departure_time_str5

    arrival_time_str6 = filtered_row4['arrival_time'].values[0]
    arrival_time6 = datetime.strptime(arrival_time_str6, '%H:%M:%S')
    new_arrival_time6 = arrival_time6 + timedelta(minutes=10)
    new_arrival_time_str6 = new_arrival_time6.strftime('%H:%M:%S')
    filtered_row4['arrival_time'] = new_arrival_time_str6

    departure_time_str6 = filtered_row4['departure_time'].values[0]
    departure_time6 = datetime.strptime(departure_time_str6, '%H:%M:%S')
    new_departure_time6 = departure_time6 + timedelta(minutes=10, seconds=5)
    new_departure_time_str6 = new_departure_time6.strftime('%H:%M:%S')
    filtered_row4['departure_time'] = new_departure_time_str6

    arrival_time_str7 = filtered_row5['arrival_time'].values[0]
    arrival_time7 = datetime.strptime(arrival_time_str7, '%H:%M:%S')
    new_arrival_time7 = arrival_time7 + timedelta(minutes=12)
    new_arrival_time_str7 = new_arrival_time7.strftime('%H:%M:%S')
    filtered_row5['arrival_time'] = new_arrival_time_str7

    departure_time_str7 = filtered_row5['departure_time'].values[0]
    departure_time7 = datetime.strptime(departure_time_str7, '%H:%M:%S')
    new_departure_time7 = departure_time7 + timedelta(minutes=12, seconds=5)
    new_departure_time_str7 = new_departure_time7.strftime('%H:%M:%S')
    filtered_row5['departure_time'] = new_departure_time_str7

    arrival_time_str8 = filtered_row6['arrival_time'].values[0]
    arrival_time8 = datetime.strptime(arrival_time_str8, '%H:%M:%S')
    new_arrival_time8= arrival_time8 + timedelta(minutes=14)
    new_arrival_time_str8 = new_arrival_time8.strftime('%H:%M:%S')
    filtered_row6['arrival_time'] = new_arrival_time_str8

    departure_time_str8 = filtered_row6['departure_time'].values[0]
    departure_time8 = datetime.strptime(departure_time_str8, '%H:%M:%S')
    new_departure_time8 = departure_time8 + timedelta(minutes=14, seconds=5)
    new_departure_time_str8 = new_departure_time8.strftime('%H:%M:%S')
    filtered_row6['departure_time'] = new_departure_time_str8

    arrival_time_str9 = filtered_row7['arrival_time'].values[0]
    arrival_time9 = datetime.strptime(arrival_time_str9, '%H:%M:%S')
    new_arrival_time9= arrival_time9 + timedelta(minutes=16)
    new_arrival_time_str9 = new_arrival_time9.strftime('%H:%M:%S')
    filtered_row7['arrival_time'] = new_arrival_time_str9

    departure_time_str9 = filtered_row7['departure_time'].values[0]
    departure_time9 = datetime.strptime(departure_time_str9, '%H:%M:%S')
    new_departure_time9 = departure_time9 + timedelta(minutes=16, seconds=5)
    new_departure_time_str9 = new_departure_time9.strftime('%H:%M:%S')
    filtered_row7['departure_time'] = new_departure_time_str9
    
    arrival_time_str10 = filtered_row8['arrival_time'].values[0]
    arrival_time10 = datetime.strptime(arrival_time_str10, '%H:%M:%S')
    new_arrival_time10= arrival_time10 + timedelta(minutes=20)
    new_arrival_time_str10 = new_arrival_time10.strftime('%H:%M:%S')
    filtered_row8['arrival_time'] = new_arrival_time_str10

    departure_time_str10 = filtered_row8['departure_time'].values[0]
    departure_time10 = datetime.strptime(departure_time_str10, '%H:%M:%S')
    new_departure_time10 = departure_time10 + timedelta(minutes=20)
    new_departure_time_str10 = new_departure_time10.strftime('%H:%M:%S')
    filtered_row8['departure_time'] = new_departure_time_str10


    

    filtered_row['stop_sequence'] =filtered_row['stop_sequence'] + 1
    filtered_row1['stop_sequence'] =filtered_row1['stop_sequence'] + 2
    filtered_row2['stop_sequence'] =filtered_row2['stop_sequence'] + 3
    filtered_row3['stop_sequence'] =filtered_row3['stop_sequence'] + 4
    filtered_row4['stop_sequence'] =filtered_row4['stop_sequence'] + 5
    filtered_row5['stop_sequence'] =filtered_row5['stop_sequence'] + 6
    filtered_row6['stop_sequence'] =filtered_row5['stop_sequence'] + 7
    filtered_row7['stop_sequence'] =filtered_row5['stop_sequence'] + 8
    filtered_row8['stop_sequence'] =filtered_row5['stop_sequence'] + 9
  

    filtered_row['pickup_type'] = 0
    filtered_row1['pickup_type'] = 0
    filtered_row2['pickup_type'] = 0
    filtered_row3['pickup_type'] = 0
    filtered_row4['pickup_type'] = 0
    filtered_row5['pickup_type'] = 0
    filtered_row6['pickup_type'] = 0
    filtered_row7['pickup_type'] = 0
    



    condition = (stop_times_txt_data['trip_id'] == trip_id) & ((stop_times_txt_data['stop_id'] == 203288) | (stop_times_txt_data['stop_id'] == 203289)) 
    # Extract the current arrival time
    current_arrival_time_str1 = stop_times_txt_data.loc[condition, 'arrival_time'].values[0]
    # Convert the arrival time to a datetime object
    current_arrival_time1 = datetime.strptime(current_arrival_time_str1, '%H:%M:%S')
    # Subtract one minute
    new_arrival_time1 = current_arrival_time1 - timedelta(minutes=1)
    # Convert back to string
    new_arrival_time_str1 = new_arrival_time1.strftime('%H:%M:%S')
    # Update the DataFrame
    stop_times_txt_data.loc[condition, 'arrival_time'] = new_arrival_time_str1

    stop_times_txt_data.loc[condition, 'pickup_type'] = 0


    rows_to_insert = [filtered_row,filtered_row1,filtered_row2,filtered_row3,filtered_row4,filtered_row5,filtered_row6,filtered_row7,filtered_row8]

    insert_df = pd.concat(rows_to_insert, ignore_index=True)

 


    index_to_insert_after = stop_times_txt_data[((stop_times_txt_data['stop_id'] == 203288) | (stop_times_txt_data['stop_id'] == 203289)) & (stop_times_txt_data['trip_id']== trip_id)].index[0]

    # Step 2: Create the DataFrames for concatenation
    df_top = stop_times_txt_data.iloc[:index_to_insert_after + 1]  # DataFrame before the insertion point
    df_bottom = stop_times_txt_data.iloc[index_to_insert_after + 1:]  # DataFrame after the insertion point

    # Step 3: Insert the new row and concatenate
    stop_times_txt_data = pd.concat([df_top, insert_df, df_bottom], ignore_index=True).reset_index(drop=True)
    stop_tines_txt_data = stop_times_txt_data.drop_duplicates()
    
    #index_to_insert_before = stop_times_txt_data[stop_times_txt_data['stop_sequence'] == 0].index[0]
    #stop_times_txt_data.loc[index_to_insert_before] = filtered_row.iloc[0]
    #stop_times_txt_data = pd.concat([stop_times_txt_data.iloc[:index_to_insert_before], filtered_row, stop_times_txt_data.iloc[index_to_insert_before:]]).reset_index(drop=True)


       
    
    return

# %%
ticker = 0

for trip1 in trip_ids2:
    process_trip1(trip1)
    ticker +=1
    print(ticker)

# %%
process_trip1('38795-71092:1000')

# %%
test_output = stop_times_txt_data[stop_times_txt_data['trip_id']=='38795-71092:1000']
test_output

# %%
stop_times_txt_data.to_csv("C:/Users/m1llz/Downloads/UNI FILES/UNISTUFF V2/new_base_case_with_smw_v4_lightrail/stop_times.txt", index=False)

# %%
shapefile_path_gtfs1 = 'C:/Users/m1llz/Downloads/UNI FILES/UNISTUFF V2/2056_stage1.zip'

# %%
import r5py
import osmnx as ox

#G=ox.graph_from_file(shapefile_path_osm, simplify = False)

transport_network = r5py.TransportNetwork(
    shapefile_path_osm,
    [
        shapefile_path_gtfs1,
    ]
)

# %%
import datetime


travel_time_matrix = r5py.TravelTimeMatrixComputer(
    transport_network,
    origins=origins,
    destinations=destinations,
    transport_modes=[r5py.TransportMode.TRANSIT, r5py.TransportMode.WALK],
    departure=datetime.datetime(2024, 8, 28, 8, 00, 00),
    departure_time_window=datetime.timedelta(hours=1),
    snap_to_network=True
).compute_travel_times()

# %%
travel_time_matrix

# %%
test_location = 146

travel_times_to_centre = travel_time_matrix[travel_time_matrix["to_id"] == test_location].copy()
travel_times_to_centre = travel_times_to_centre.set_index("from_id")[["travel_time"]]

grid_with_travel_time_to_centre = (
    filtered_gdf2.set_index("id").join(travel_times_to_centre)
)

grid_with_travel_time_to_centre

# %%
grid_with_travel_time_to_centre.explore(
    column="travel_time",
    cmap="RdYlGn",
    tiles="CartoDB.Positron",
)

# %%
median_travel_times = travel_time_matrix.groupby("from_id")["travel_time"].median()
median_travel_times

# %%
grid_with_median_travel_times = (
    filtered_gdf2.set_index("id").join(median_travel_times)
)

grid_with_median_travel_times.explore(
    column="travel_time", 
    cmap="RdYlGn_r",
    tiles="CartoDB.Positron",
)

# %%
merged_traveltime_matrix = pd.merge(travel_time_matrix, filtered_gdf2, left_on='to_id', right_on='TZ16_CODE', how='left')

merged_traveltime_matrix

# %%
threshold =60
# Count the number of opportunities from each grid cell
opportunities = merged_traveltime_matrix.loc[merged_traveltime_matrix["travel_time"]<=threshold].groupby("from_id")["EMP_2016"].sum().reset_index()

# Rename the column for more intuitive one
opportunities = opportunities.rename(columns={"from_id": "num_opportunities"})

opportunities

# %%
opportunities2 = filtered_gdf2.merge(opportunities, left_on="id", right_on="num_opportunities")
opportunities2

# %%
opportunities.to_csv("C:/Users/m1llz/Downloads/opportunities_2001.csv", index=False)

# %%
import matplotlib.pyplot as plt

ax = opportunities2.plot(column="EMP_2016_y", figsize=(10,5), legend=True)
ax.set_title(f"Number of opportunities within {threshold} minutes."); 
ax.invert_yaxis()
ax.invert_xaxis()
plt.set_cmap('RdYlGn')
plt.show()
#plt.savefig('C:/Users/m1llz/Downloads/plot.jpg', format='jpg')

# %%
opportunities2['APW'] =(opportunities2['EMP_2016_x'] * opportunities2['EMP_2016_y'])/opportunities2['EMP_2016_x'].sum()

#opportunities2
total_APW = opportunities2['APW'].sum()
print(total_APW)
